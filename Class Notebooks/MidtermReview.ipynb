# %% [markdown]
# # Midterm Review Day
#
# The goal today is to refresh our memory of how to utilize the Python basics and practice things that will almost certainly show up on the midterm

# %%
from datascience import *
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
from scipy.stats import gaussian_kde

## Read in a CSV data file from the web.
parks = Table.read_table('https://faculty.ung.edu/rsinn/data/nationalparks.csv').drop(5,6,9,10,11,12,13,14)
sky = Table.read_table('https://faculty.ung.edu/rsinn/data/skyscrapers_v2.csv')

# %% [markdown]
# ## Practice Problems

# %% [markdown]
# ### Problem 1: Distances in Kilometers
#
# The **distances** table below displays distances within the USA but in kilometers (km). Your task:
#
# 1. Use array arithmetic to convert all the distances to miles given that there are approximate $1.609$ km per mile.
# 2. Add a column to the table **distances** with the title 'Distance (miles)' that shows the results of the conversions done above.

# %%
route = ('New York City to Philadelphia', 'Los Angeles to San Diego', 'Miami to Orlando', 'Washington D.C. to Boston', 'Chicago to Atlanta', 'Dallas to Denver', 'Seattle to San Francisco', 'Las Vegas to Houston', 'Route 66: Full Historic Length' )
km = make_array(152.0, 193.1, 378.2, 708.1, 1153.9, 1273.0, 1298.1, 2364.0, 3940.0)
distancesUSA = Table().with_columns('Route', route, 'Distance (km)', km)
distancesUSA.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Route</th> <th>Distance (km)</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>New York City to Philadelphia </td> <td>152          </td>
#         </tr>
#         <tr>
#             <td>Los Angeles to San Diego      </td> <td>193.1        </td>
#         </tr>
#         <tr>
#             <td>Miami to Orlando              </td> <td>378.2        </td>
#         </tr>
#         <tr>
#             <td>Washington D.C. to Boston     </td> <td>708.1        </td>
#         </tr>
#         <tr>
#             <td>Chicago to Atlanta            </td> <td>1153.9       </td>
#         </tr>
#         <tr>
#             <td>Dallas to Denver              </td> <td>1273         </td>
#         </tr>
#         <tr>
#             <td>Seattle to San Francisco      </td> <td>1298.1       </td>
#         </tr>
#         <tr>
# ...

# %% [markdown]
# ### Problem 2: np.arange()
#
# Create the first 10 powers of 3 starting with $3^1 = 3$.

# %% [markdown]
# ### Problem 3: Evaluate the Expressions Below

# %% [markdown]
# $\left(3\frac{1}{2}\right)^4 - \left(\frac{1}{2}\right)^4 + 1,950 = $

# %% [markdown]
# $\left(4\frac{1}{2}\right)^3 + \left(3\frac{1}{4}\right) \times 2^6 - 208$

# %% [markdown]
# $\left(6\frac{1}{2}\right)^2 + \left(2\frac{3}{4}\right) \times 2^2 + 1,973$

# %% [markdown]
# $\left(8\frac{1}{2}\right)^2 - \left(1\frac{1}{2}\right)^2 + 4^6 + 974$

# %% [markdown]
# $\left(7\frac{1}{2}\right)^4 - \left(2\frac{1}{2}\right)^4 + 2,000$

# %% [markdown]
# $\left(5\frac{1}{2}\right)^3 + \left(\frac{1}{2}\right)^3 + 1,833$

# %% [markdown]
# $\left(9\frac{1}{2}\right)^2 + \left(\frac{1}{2}\right)^2 + 2^7 - 38$

# %% [markdown]
# $\left(6\frac{1}{4}\right) \times 4^3 + \left(3\frac{1}{2}\right)^2 - \left(\frac{1}{2}\right)^2 + 1,588$

# %% [markdown]
# ### Problem 4: National Parks
#
# 1. Find the largest 5 national parks in terms of **acres**.
# 2. Find the 5 national parks that had the most **visitors**.

# %% [markdown]
# ### Problem 5: Skyscrapers
#
# Using the **sky** table:
#
# 1. Determine the number of Atlanta skyscrapers.
# 2. Determine the number of Chicago skyscrapers taller than 325 meters.
# 3. Find the tallest 4 skyscrapers that are located in Dallas.
# 4. What are the oldest 10 skyscrapers in the table?
# 5. What the tallest 7 steel buildings in the table?

# %% [markdown]
# ### Problem 6: Histogram of **height** of Cincinnati Skyscrapers

# %% [markdown]
# ### Problem 7: Scatter Plot Comparing Height of Skyscrapers to Year Completed

# %% [markdown]
# ### Problem 8: Pareto Chart of Cities in the Skyscraper Table and Number of Skyscrapers in that City

# %% [markdown]
# ### Problem 9: Create an array with all multiples of 5 between 0 and 10,000.

# %% [markdown]
# ### Problem 10: What are all the Column Titles in the Parks Table?
