# %% [markdown]
# # Midterm Study Guide
#
# The midterm is closed response (multiple choice, check all that apply, and True/False). You will be allowed to have a printed-out Study Guide during the test which is on D2L.

# %% [markdown]
# ## Initialization Code Block

# %%
## Do not change this cell, only execute it. 
## This cell initializes Python so that datascience, numpy and scipy packages are ready to use.

from datascience import *
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
import numpy as np
import pandas as pd
import scipy.stats as stats

## Read in the following CSV files as tables so we have data for examples.

births = Table.read_table('baby.csv')
pers = Table.read_table('https://faculty.ung.edu/rsinn/personality.csv')

# %% [markdown]
# ## <span style="color:blue;font-weight:bold;font-size:1.15em">Topics</span>

# %% [markdown]
# ## .select

# %% [markdown]
# ## .column

# %% [markdown]
# ## .where

# %% [markdown]
# ## .sort

# %% [markdown]
# ## .take

# %% [markdown]
# ## .num_rows and .num_columns

# %% [markdown]
# ## .relabel
#
# Changes a column title.

# %% [markdown]
# ## .with_columns
#
# Used to create a column or columns within a table.
#
# **Example**
# Table().with_columns('Column Title', array_data)

# %% [markdown]
# ## .scatter

# %% [markdown]
# ## .boxplot
#
# Picture of the 5-number summary.
#
# We can use the boxplot to check for outliers:
#
# - Upper Fence = Q3 + 1.5 * IQR
# - Lower Fence = Q1 - 1.5 * IQR
#
# IQR = Q3 - Q1

# %%
data = pers.column('Sleep')
plots.boxplot(data)
plots.xlabel('Sleep') ;

# %% [markdown]
# ### The following descriptive statistics for the SLEEP data above will help determine fences and outliers:
# - Q1 = 5.0
# - Median = 6.5
# - Q3 = 7.5
#
# ### Determine if the following data points are outliers in the SLEEP distribution example data above.
# - 0.75
# - 1.25
# - 2.50
# - 11.1

# %% [markdown]
# ## .hist

# %% [markdown]
# ### Shape of the Histogram: ...

# %% [markdown]
# ## .plot
#
# Line plots, sadly, do not always display well.

# %%
pers.plot('CHS', 'Opt')

# %% [markdown]
# ## .group and .pivot
#
# Let's create a table called **perfect** to use as an example for these two table methods.

# %%
perfect = pers.select('Sex', 'SitClass', 'Perf')
perfect.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Sex</th> <th>SitClass</th> <th>Perf</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>M   </td> <td>F       </td> <td>105 </td>
#         </tr>
#         <tr>
#             <td>F   </td> <td>M       </td> <td>105 </td>
#         </tr>
#         <tr>
#             <td>M   </td> <td>B       </td> <td>73  </td>
#         </tr>
#         <tr>
#             <td>F   </td> <td>M       </td> <td>90  </td>
#         </tr>
#         <tr>
#             <td>M   </td> <td>F       </td> <td>95  </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (124 rows omitted)</p>

# %% [markdown]
# ## .group
#
# Category variable analysis.

# %% [markdown]
# ## .pivot
#
# For analyzing 2 category variables.

# %% [markdown]
# # Functions
#
# ## np.arange
#
# Inputs:
#
# 1. Start criteria
# 2. Stop criteria
# 3. Increment

# %% [markdown]
# ## make_array

# %% [markdown]
# ## np.mean, np.median, np.pi, np.e, min, max, sum

# %%
example = pers.column('Age')

# %% [markdown]
# ## np.diff and np.cumsum
#
# Let's create the example arrays
#
# - $x = \{0,2,3,7,12\}$
# - $y = \{1,  4,  7, 10, 13, 16, 19\}$
#
# so that we can demonstrate how these two function work.

# %%
x = make_array(0, 2, 3, 7, 12)
y = np.arange(1,20,3)
